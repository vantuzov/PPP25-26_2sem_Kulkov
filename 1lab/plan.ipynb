# %% [markdown]
# # **Неделя 1: Анализ и проектирование**

# %% [markdown]
# ## Изучение требований к объектно-ориентированной реализации

# %% [markdown]
# *
# *
# *

# %% [markdown]
# ## Создание структуры проекта

# %% [markdown]
# * Иерархия классов
# * Взаимосвязи между компонентами
# * Система контроля версий

# %% [markdown]
# ## Проектирование архитектуры:

# %% [markdown]
# * Диаграммы классов
# * Схема взаимодействия объектов
# * План реализации основных компонентов

# %% [markdown]
# ## Подготовка документации:

# %% [markdown]
# * Техническое задание
# * Описание основных классов
# * План реализации

# %% [markdown]
#  # **Неделя 2: Реализация базового функционала**

# %% [markdown]
# ## Разработка базового класса фигуры:

# %% [markdown]
# * Общие атрибуты
# * Основные методы
# * Система цветов фигур

# %% [markdown]
# ## Создание классов для стандартных фигур:

# %% [markdown]
# * Пешка
# * Конь
# * Слон
# * Ладья
# * Ферзь
# * Король

# %% [markdown]
# ## Реализация класса доски:

# %% [markdown]
# * Структура хранения фигур
# * Система координат
# * Визуализация
